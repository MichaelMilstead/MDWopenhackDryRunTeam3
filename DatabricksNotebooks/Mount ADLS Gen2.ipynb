# %%
configs = {"fs.azure.account.auth.type": "OAuth",
           "fs.azure.account.oauth.provider.type": "org.apache.hadoop.fs.azurebfs.oauth2.ClientCredsTokenProvider",
           "fs.azure.account.oauth2.client.id": dbutils.secrets.get(scope = "keyvault-secrets", key = "adls-client-id"),
           "fs.azure.account.oauth2.client.secret": dbutils.secrets.get(scope = "keyvault-secrets", key = "adls-client-secret"),
           "fs.azure.account.oauth2.client.endpoint": "https://login.microsoftonline.com/32028639-7601-4d62-bf91-7b86126e4bea/oauth2/token"}
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
dbutils.fs.unmount("/mnt/datalake1")

dbutils.fs.mount(
  source = "abfss://datalake1@southridgeadlsteam3.dfs.core.windows.net/",
  mount_point = "/mnt/datalake1",
  extra_configs = configs)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/mnt/datalake1 has been unmounted.
# <span class="ansired">Out[</span><span class="ansired">15</span><span class="ansired">]: </span>True
# </div>

# %%
dbutils.fs.ls("/mnt/datalake1/fourthcoffee-rawrentals")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">16</span><span class="ansired">]: </span>
# [FileInfo(path=&apos;dbfs:/mnt/datalake1/fourthcoffee-rawrentals/Actors.csv&apos;, name=&apos;Actors.csv&apos;, size=20590),
#  FileInfo(path=&apos;dbfs:/mnt/datalake1/fourthcoffee-rawrentals/Customers.csv&apos;, name=&apos;Customers.csv&apos;, size=30745),
#  FileInfo(path=&apos;dbfs:/mnt/datalake1/fourthcoffee-rawrentals/MovieActors.csv&apos;, name=&apos;MovieActors.csv&apos;, size=324940),
#  FileInfo(path=&apos;dbfs:/mnt/datalake1/fourthcoffee-rawrentals/Movies.csv&apos;, name=&apos;Movies.csv&apos;, size=81936),
# ...
